# %%
from IPython.display import display, HTML
display(HTML("<style>.container { width:95% !important; }</style>"))
# Out:
# <style>.container { width:95% !important; }</style>

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import glob
import pandas as pd
import numpy as np
from sglm.helpers import filehelpers as fh, dfhelpers as dfh
from pathlib import Path

# %%
# base_location = Path(r'/Users/Josh/Documents/GitHub/sabatinilab-glm/sglm/outputs')
base_location = Path(r'/Users/Josh/Documents/GitHub/sabatinilab-glm/sglm/outputs-old')


# load_folder = base_location / Path(r'Figure_1_2')
# h5_beta_locations = str((load_folder / Path(r'all/hs2-w*-ft/coefs/*_best_coeffs.h5')).resolve())
# h5_beta_locations = str((load_folder / Path(r'all/hypswp-50_*-ft/coefs/*_best_coeffs.h5')).resolve())

# load_folder = base_location / Path(r'Figure_1_2')
# h5_beta_locations = str((load_folder / Path(r'all/hypswp-50-wds*-ft/coefs/*_best_coeffs.h5')).resolve())

# load_folder = base_location / Path(r'Figure_1_2')
# h5_beta_locations = str((load_folder / Path(r'all\f1*-ft\coefs\*_best_coeffs.h5')).resolve())
# load_folder = base_location / Path(r'Figure_3')
# h5_beta_locations = str((load_folder / Path(r'all\f3*-ft\coefs\*_best_coeffs.h5')).resolve())
# load_folder = base_location / Path(r'Figure_4_g1')
# h5_beta_locations = str((load_folder / Path(r'all\f4*-ft\coefs\*_best_coeffs.h5')).resolve())
# load_folder = base_location / Path(r'Figure_4_g2')
# h5_beta_locations = str((load_folder / Path(r'all\f4*-ft\coefs\*_best_coeffs.h5')).resolve())
# load_folder = base_location / Path(r'Figure_5_g1')
# h5_beta_locations = str((load_folder / Path(r'all\f5*-ft\coefs\*_best_coeffs.h5')).resolve())
# load_folder = base_location / Path(r'Figure_5_g2')
# h5_beta_locations = str((load_folder / Path(r'all\f5*-ft\coefs\*_best_coeffs.h5')).resolve())
# load_folder = base_location / Path(r'Figure_5_g5')
# h5_beta_locations = str((load_folder / Path(r'all\f5*-ft\coefs\*_best_coeffs.h5')).resolve())

load_folder = base_location / Path(r'Figure_7_g1--20_20sft')
h5_beta_locations = str((load_folder / Path(r'all/tet*/coefs/*_best_coeffs.h5')).resolve())


# out_folder = base_location / Path(r'final_outputs_rev_hps-wds3')
out_folder = base_location / Path(r'final_outputs_old')

# h5_beta_locations = Path('/Users/josh/Dropbox (HMS)/jz/Tetanus/1194_1195_1214_1258_1259_2_best_coeffs.h5')
out_loc = str((out_folder).resolve())
h5_beta_locations = glob.glob(h5_beta_locations)

# %%
h5_beta_locations
# Out:
# ['C:\\Users\\Josh\\Documents\\GitHub\\sabatinilab-glm\\sglm\\outputs-old\\Figure_7_g1--20_20sft\\all\\tet_run_20230328--20_20sft_0-ft\\coefs\\732_735_736_776_0_max_iter10000__fit_interceptFalse__alpha0____0__l1_ratio0____0_best_coeffs.h5',
#  'C:\\Users\\Josh\\Documents\\GitHub\\sabatinilab-glm\\sglm\\outputs-old\\Figure_7_g1--20_20sft\\all\\tet_run_20230328--20_20sft_1-ft\\coefs\\732_735_736_776_1_max_iter10000__fit_interceptFalse__alpha0____0__l1_ratio0____0_best_coeffs.h5']

# %%
h5_lst = []
for h5_coef_fn in h5_beta_locations:
    h5f = pd.HDFStore(h5_coef_fn)
#                                                    /gDA_ctrl_0_0_base_simple_max_iter10000__fit_in...  gDA_ctrl_0_run_num=5
#                                                    /gDA_ctrl_0_0_base_simple_max_iter10000__fit_in...  gDA_ctrl_0_run_num=6
#                                                    /gDA_ctrl_0_0_base_simple_max_iter10000__fit_in...  gDA_ctrl_0_run_num=7
#                                                    /gDA_ctrl_0_0_base_simple_max_iter10000__fit_in...  gDA_ctrl_0_run_num=8
#                                                    /gDA_ctrl_0_0_base_simple_max_iter10000__fit_in...  gDA_ctrl_0_run_num=9
#                                                    /gDA_ctrl_0_1_base_words_max_iter10000__fit_int...  gDA_ctrl_1_run_num=0
#                                                    /gDA_ctrl_0_1_base_words_max_iter10000__fit_int...  gDA_ctrl_1_run_num=1
#                                                    /gDA_ctrl_0_1_base_words_max_iter10000__fit_int...  gDA_ctrl_1_run_num=2
#                                                    /gDA_ctrl_0_1_base_words_max_iter10000__fit_int...  gDA_ctrl_1_run_num=3
#                                                    /gDA_ctrl_0_1_base_words_max_iter10000__fit_int...  gDA_ctrl_1_run_num=4
#                                                    /gDA_ctrl_0_1_base_words_max_iter10000__fit_int...  gDA_ctrl_1_run_num=5
#                                                    /gDA_ctrl_0_1_base_words_max_iter10000__fit_int...  gDA_ctrl_1_run_num=6
#                                                    /gDA_ctrl_0_1_base_words_max_iter10000__fit_int...  gDA_ctrl_1_run_num=7
#                                                    /gDA_ctrl_0_1_base_words_max_iter10000__fit_int...  gDA_ctrl_1_run_num=8
#                                                    /gDA_ctrl_0_1_base_words_max_iter10000__fit_int...  gDA_ctrl_1_run_num=9
# C:\Users\Josh\Documents\GitHub\sabatinilab-glm\... /gDA_tet_1_0_base_simple_max_iter10000__fit_int...   gDA_tet_0_run_num=0
#                                                    /gDA_tet_1_0_base_simple_max_iter10000__fit_int...   gDA_tet_0_run_num=1
#                                                    /gDA_tet_1_0_base_simple_max_iter10000__fit_int...   gDA_tet_0_run_num=2
#                                                    /gDA_tet_1_0_base_simple_max_iter10000__fit_int...   gDA_tet_0_run_num=3
#                                                    /gDA_tet_1_0_base_simple_max_iter10000__fit_int...   gDA_tet_0_run_num=4
#                                                    /gDA_tet_1_0_base_simple_max_iter10000__fit_int...   gDA_tet_0_run_num=5
#                                                    /gDA_tet_1_0_base_simple_max_iter10000__fit_int...   gDA_tet_0_run_num=6
#                                                    /gDA_tet_1_0_base_simple_max_iter10000__fit_int...   gDA_tet_0_run_num=7
#                                                    /gDA_tet_1_0_base_simple_max_iter10000__fit_int...   gDA_tet_0_run_num=8
#                                                    /gDA_tet_1_0_base_simple_max_iter10000__fit_int...   gDA_tet_0_run_num=9
#                                                    /gDA_tet_1_1_base_words_max_iter10000__fit_inte...   gDA_tet_1_run_num=0
#                                                    /gDA_tet_1_1_base_words_max_iter10000__fit_inte...   gDA_tet_1_run_num=1
#                                                    /gDA_tet_1_1_base_words_max_iter10000__fit_inte...   gDA_tet_1_run_num=2
#                                                    /gDA_tet_1_1_base_words_max_iter10000__fit_inte...   gDA_tet_1_run_num=3
#                                                    /gDA_tet_1_1_base_words_max_iter10000__fit_inte...   gDA_tet_1_run_num=4
#                                                    /gDA_tet_1_1_base_words_max_iter10000__fit_inte...   gDA_tet_1_run_num=5
#                                                    /gDA_tet_1_1_base_words_max_iter10000__fit_inte...   gDA_tet_1_run_num=6
#                                                    /gDA_tet_1_1_base_words_max_iter10000__fit_inte...   gDA_tet_1_run_num=7
#                                                    /gDA_tet_1_1_base_words_max_iter10000__fit_inte...   gDA_tet_1_run_num=8
#                                                    /gDA_tet_1_1_base_words_max_iter10000__fit_inte...   gDA_tet_1_run_num=9
#
#                                                                                                               name  \
# fn                                                 key
# C:\Users\Josh\Documents\GitHub\sabatinilab-glm\... /gDA_ctrl_0_0_base_simple_max_iter10000__fit_in...  base_simple
#                                                    /gDA_ctrl_0_0_base_simple_max_iter10000__fit_in...  base_simple
#                                                    /gDA_ctrl_0_0_base_simple_max_iter10000__fit_in...  base_simple
#                                                    /gDA_ctrl_0_0_base_simple_max_iter10000__fit_in...  base_simple
#                                                    /gDA_ctrl_0_0_base_simple_max_iter10000__fit_in...  base_simple
#                                                    /gDA_ctrl_0_0_base_simple_max_iter10000__fit_in...  base_simple
#                                                    /gDA_ctrl_0_0_base_simple_max_iter10000__fit_in...  base_simple
#                                                    /gDA_ctrl_0_0_base_simple_max_iter10000__fit_in...  base_simple
#                                                    /gDA_ctrl_0_0_base_simple_max_iter10000__fit_in...  base_simple
#                                                    /gDA_ctrl_0_0_base_simple_max_iter10000__fit_in...  base_simple
#                                                    /gDA_ctrl_0_1_base_words_max_iter10000__fit_int...   base_words
#                                                    /gDA_ctrl_0_1_base_words_max_iter10000__fit_int...   base_words
#                                                    /gDA_ctrl_0_1_base_words_max_iter10000__fit_int...   base_words
#                                                    /gDA_ctrl_0_1_base_words_max_iter10000__fit_int...   base_words
#                                                    /gDA_ctrl_0_1_base_words_max_iter10000__fit_int...   base_words
#                                                    /gDA_ctrl_0_1_base_words_max_iter10000__fit_int...   base_words
#                                                    /gDA_ctrl_0_1_base_words_max_iter10000__fit_int...   base_words
#                                                    /gDA_ctrl_0_1_base_words_max_iter10000__fit_int...   base_words
#                                                    /gDA_ctrl_0_1_base_words_max_iter10000__fit_int...   base_words
#                                                    /gDA_ctrl_0_1_base_words_max_iter10000__fit_int...   base_words
# C:\Users\Josh\Documents\GitHub\sabatinilab-glm\... /gDA_tet_1_0_base_simple_max_iter10000__fit_int...  base_simple
#                                                    /gDA_tet_1_0_base_simple_max_iter10000__fit_int...  base_simple
#                                                    /gDA_tet_1_0_base_simple_max_iter10000__fit_int...  base_simple
#                                                    /gDA_tet_1_0_base_simple_max_iter10000__fit_int...  base_simple
#                                                    /gDA_tet_1_0_base_simple_max_iter10000__fit_int...  base_simple
#                                                    /gDA_tet_1_0_base_simple_max_iter10000__fit_int...  base_simple
#                                                    /gDA_tet_1_0_base_simple_max_iter10000__fit_int...  base_simple
#                                                    /gDA_tet_1_0_base_simple_max_iter10000__fit_int...  base_simple
#                                                    /gDA_tet_1_0_base_simple_max_iter10000__fit_int...  base_simple
#                                                    /gDA_tet_1_0_base_simple_max_iter10000__fit_int...  base_simple
#                                                    /gDA_tet_1_1_base_words_max_iter10000__fit_inte...   base_words
#                                                    /gDA_tet_1_1_base_words_max_iter10000__fit_inte...   base_words
#                                                    /gDA_tet_1_1_base_words_max_iter10000__fit_inte...   base_words
#                                                    /gDA_tet_1_1_base_words_max_iter10000__fit_inte...   base_words
#                                                    /gDA_tet_1_1_base_words_max_iter10000__fit_inte...   base_words
#                                                    /gDA_tet_1_1_base_words_max_iter10000__fit_inte...   base_words
#                                                    /gDA_tet_1_1_base_words_max_iter10000__fit_inte...   base_words
#                                                    /gDA_tet_1_1_base_words_max_iter10000__fit_inte...   base_words
#                                                    /gDA_tet_1_1_base_words_max_iter10000__fit_inte...   base_words
#                                                    /gDA_tet_1_1_base_words_max_iter10000__fit_inte...   base_words
#
#                                                                                                                   timestamp  \
# fn                                                 key
# C:\Users\Josh\Documents\GitHub\sabatinilab-glm\... /gDA_ctrl_0_0_base_simple_max_iter10000__fit_in...  26.629116773605347 s
#                                                    /gDA_ctrl_0_0_base_simple_max_iter10000__fit_in...   72.73085165023804 s
#                                                    /gDA_ctrl_0_0_base_simple_max_iter10000__fit_in...  118.62785792350769 s
#                                                    /gDA_ctrl_0_0_base_simple_max_iter10000__fit_in...  163.33364510536194 s
#                                                    /gDA_ctrl_0_0_base_simple_max_iter10000__fit_in...  209.48674154281616 s
#                                                    /gDA_ctrl_0_0_base_simple_max_iter10000__fit_in...    256.077595949173 s
#                                                    /gDA_ctrl_0_0_base_simple_max_iter10000__fit_in...   301.2388503551483 s
#                                                    /gDA_ctrl_0_0_base_simple_max_iter10000__fit_in...  346.52849555015564 s
#                                                    /gDA_ctrl_0_0_base_simple_max_iter10000__fit_in...   391.4938819408417 s
#                                                    /gDA_ctrl_0_0_base_simple_max_iter10000__fit_in...  437.79977083206177 s
#                                                    /gDA_ctrl_0_1_base_words_max_iter10000__fit_int...   54.89525651931763 s
#                                                    /gDA_ctrl_0_1_base_words_max_iter10000__fit_int...  101.29445004463196 s
#                                                    /gDA_ctrl_0_1_base_words_max_iter10000__fit_int...  146.07598638534546 s
#                                                    /gDA_ctrl_0_1_base_words_max_iter10000__fit_int...  190.56173014640808 s
#                                                    /gDA_ctrl_0_1_base_words_max_iter10000__fit_int...  238.07265853881836 s
#                                                    /gDA_ctrl_0_1_base_words_max_iter10000__fit_int...  283.80630373954773 s
#                                                    /gDA_ctrl_0_1_base_words_max_iter10000__fit_int...  328.98401069641113 s
#                                                    /gDA_ctrl_0_1_base_words_max_iter10000__fit_int...   373.9142186641693 s
#                                                    /gDA_ctrl_0_1_base_words_max_iter10000__fit_int...   419.9480690956116 s
#                                                    /gDA_ctrl_0_1_base_words_max_iter10000__fit_int...    465.483021736145 s
# C:\Users\Josh\Documents\GitHub\sabatinilab-glm\... /gDA_tet_1_0_base_simple_max_iter10000__fit_int...  495.28395557403564 s
#                                                    /gDA_tet_1_0_base_simple_max_iter10000__fit_int...   540.3634450435638 s
#                                                    /gDA_tet_1_0_base_simple_max_iter10000__fit_int...    585.869975566864 s
#                                                    /gDA_tet_1_0_base_simple_max_iter10000__fit_int...    630.423178434372 s
#                                                    /gDA_tet_1_0_base_simple_max_iter10000__fit_int...   675.1287682056427 s
#                                                    /gDA_tet_1_0_base_simple_max_iter10000__fit_int...   720.3594954013824 s
#                                                    /gDA_tet_1_0_base_simple_max_iter10000__fit_int...   765.3166851997375 s
#                                                    /gDA_tet_1_0_base_simple_max_iter10000__fit_int...   812.7527434825897 s
#                                                    /gDA_tet_1_0_base_simple_max_iter10000__fit_int...    859.572681427002 s
#                                                    /gDA_tet_1_0_base_simple_max_iter10000__fit_int...   905.4013729095459 s
#                                                    /gDA_tet_1_1_base_words_max_iter10000__fit_inte
#                                                    /gDA_ctrl_0_0_base_simple_max_iter10000__fit_in...                             NaN
#                                                    /gDA_ctrl_0_0_base_simple_max_iter10000__fit_in...                             NaN
#                                                    /gDA_ctrl_0_1_base_words_max_iter10000__fit_int...                       -0.092821
#                                                    /gDA_ctrl_0_1_base_words_max_iter10000__fit_int...                       -0.202814
#                                                    /gDA_ctrl_0_1_base_words_max_iter10000__fit_int...                        0.106162
#                                                    /gDA_ctrl_0_1_base_words_max_iter10000__fit_int...                       -0.112591
#                                                    /gDA_ctrl_0_1_base_words_max_iter10000__fit_int...                        0.013904
#                                                    /gDA_ctrl_0_1_base_words_max_iter10000__fit_int...                       -0.023803
#                                                    /gDA_ctrl_0_1_base_words_max_iter10000__fit_int...                       -0.146892
#                                                    /gDA_ctrl_0_1_base_words_max_iter10000__fit_int...                       -0.139411
#                                                    /gDA_ctrl_0_1_base_words_max_iter10000__fit_int...                        0.076264
#                                                    /gDA_ctrl_0_1_base_words_max_iter10000__fit_int...                       -0.130382
# C:\Users\Josh\Documents\GitHub\sabatinilab-glm\... /gDA_tet_1_0_base_simple_max_iter10000__fit_int...                             NaN
#                                                    /gDA_tet_1_0_base_simple_max_iter10000__fit_int...                             NaN
#                                                    /gDA_tet_1_0_base_simple_max_iter10000__fit_int...                             NaN
#                                                    /gDA_tet_1_0_base_simple_max_iter10000__fit_int...                             NaN
#                                                    /gDA_tet_1_0_base_simple_max_iter10000__fit_int...                             NaN
#                                                    /gDA_tet_1_0_base_simple_max_iter10000__fit_int...                             NaN
#                                                    /gDA_tet_1_0_base_simple_max_iter10000__fit_int...                             NaN
#                                                    /gDA_tet_1_0_base_simple_max_iter10000__fit_int...                             NaN
#                                                    /gDA_tet_1_0_base_simple_max_iter10000__fit_int...                             NaN
#                                                    /gDA_tet_1_0_base_simple_max_iter10000__fit_int...                             NaN
#                                                    /gDA_tet_1_1_base_words_max_iter10000__fit_inte...                       -0.274305
#                                                    /gDA_tet_1_1_base_words_max_iter10000__fit_inte...                       -0.183193
#                                                    /gDA_tet_1_1_base_words_max_iter10000__fit_inte...                       -0.101035
#                                                    /gDA_tet_1_1_base_words_max_iter10000__fit_inte...                       -0.198518
#                                                    /gDA_tet_1_1_base_words_max_iter10000__fit_inte...                       -0.133330
#                                                    /gDA_tet_1_1_base_words_max_iter10000__fit_inte...                       -0.235541
#                                                    /gDA_tet_1_1_base_words_max_iter10000__fit_inte...                       -0.242992
#                                                    /gDA_tet_1_1_base_words_max_iter10000__fit_inte...                       -0.158767
#                                                    /gDA_tet_1_1_base_words_max_iter10000__fit_inte...                       -0.275076
#                                                    /gDA_tet_1_1_base_words_max_iter10000__fit_inte...                       -0.237736
#
#                                                                                                        photometrySideInIndexab_sft_19  \
# fn                                                 key
# C:\Users\Josh\Documents\GitHub\sabatinilab-glm\... /gDA_ctrl_0_0_base_simple_max_iter10000__fit_in...                             NaN
#                                                    /gDA_ctrl_0_0_base_simple_max_iter10000__fit_in...                             NaN
#                                                    /gDA_ctrl_0_0_base_simple_max_iter10000__fit_in...                             NaN
#                                                    /gDA_ctrl_0_0_base_simple_max_iter10000__fit_in...                             NaN
#                                                    /gDA_ctrl_0_0_base_simple_max_iter10000__fit_in...                             NaN
#                                                    /gDA_ctrl_0_0_base_simple_max_iter10000__fit_in...                             NaN
#                                                    /gDA_ctrl_0_0_base_simple_max_iter10000__fit_in...                             NaN
#                                                    /gDA_ctrl_0_0_base_simple_max_iter10000__fit_in...                             NaN
#                                                    /gDA_ctrl_0_0_base_simple_max_iter10000__fit_in...                             NaN
#                                                    /gDA_ctrl_0_0_base_simple_max_iter10000__fit_in...                             NaN
#                                                    /gDA_ctrl_0_1_base_words_max_iter10000__fit_int...                       -0.144427
#                                                    /gDA_ctrl_0_1_base_words_max_iter10000__fit_int...                       -0.051805
#                                                    /gDA_ctrl_0_1_base_words_max_iter10000__fit_int...                        0.081124
#                                                    /gDA_ctrl_0_1_base_words_max_iter10000__fit_int...                       -0.181344
#                                                    /gDA_ctrl_0_1_base_words_max_iter10000__fit_int...                        0.060371
#                                                    /gDA_ctrl_0_1_base_words_max_iter10000__fit_int...                       -0.066062
#                                                    /gDA_ctrl_0_1_base_words_max_iter10000__fit_int...                       -0.115330
#                                                    /gDA_ctrl_0_1_base_words_max_iter10000__fit_int...                       -0.101459
#                                                    /gDA_ctrl_0_1_base_words_max_iter10000__fit_int...                        0.116575
#                                                    /gDA_ctrl_0_1_base_words_max_iter10000__fit_int...                       -0.170939
# C:\Users\Josh\Documents\GitHub\sabatinilab-glm\... /gDA_tet_1_0_base_simple_max_iter10000__fit_int...                             NaN
#                                                    /gDA_tet_1_0_base_simple_max_iter10000__fit_int...                             NaN
#                                                    /gDA_tet_1_0_base_simple_max_iter10000__fit_int...                             NaN
#                                                    /gDA_tet_1_0_base_simple_max_iter10000__fit_int...                             NaN
#                                                    /gDA_tet_1_0_base_simple_max_iter10000__fit_int...                             NaN
#                                                    /gDA_tet_1_0_base_simple_max_iter10000__fit_int...                             NaN
#                                                    /gDA_tet_1_0_base_simple_max_iter10000__fit_int...                             NaN
#                                                    /gDA_tet_1_0_base_simple_max_iter10000__fit_int...                             NaN
#                                                    /gDA_tet_1_0_base_simple_max_iter10000__fit_int...                             NaN
#                                                    /gDA_tet_1_0_base_simple_max_iter10000__fit_int...                             NaN
#                                                    /gDA_tet_1_1_base_words_max_iter10000__fit_inte...                       -0.292254
#                                                    /gDA_tet_1_1_base_words_max_iter10000__fit_inte...                       -0.212981
#                                                    /gDA_tet_1_1_base_words_max_iter10000__fit_inte...                       -0.147834
#                                                    /gDA_tet_1_1_base_words_max_iter10000__fit_inte...                       -0.150503
#                                                    /gDA_tet_1_1_base_words_max_iter10000__fit_inte...                       -0.191265
#                                                    /gDA_tet_1_1_base_words_max_iter10000__fit_inte...                       -0.226448
#                                                    /gDA_tet_1_1_base_words_max_iter10000__fit_inte...                       -0.184577
#                                                    /gDA_tet_1_1_base_words_max_iter10000__fit_inte...                       -0.116572
#                                                    /gDA_tet_1_1_base_words_max_iter10000__fit_inte...                       -0.236773
#                                                    /gDA_tet_1_1_base_words_max_iter10000__fit_inte...                       -0.248739
#
#                                                                                                        photometrySideInIndexab_sft_20
# fn                                                 key
# C:\Users\Josh\Documents\GitHub\sabatinilab-glm\... /gDA_ctrl_0_0_base_simple_max_iter10000__fit_in...                             NaN
#                                                    /gDA_ctrl_0_0_base_simple_max_iter10000__fit_in...                             NaN
#                                                    /gDA_ctrl_0_0_base_simple_max_iter10000__fit_in...                             NaN
#                                                    /gDA_ctrl_0_0_base_simple_max_iter10000__fit_in...                             NaN
#                                                    /gDA_ctrl_0_0_base_simple_max_iter10000__fit_in...                             NaN
#                                                    /gDA_ctrl_0_0_base_simple_max_iter10000__fit_in...                             NaN
#                                                    /gDA_ctrl_0_0_base_simple_max_iter10000__fit_in...                             NaN
#                                                    /gDA_ctrl_0_0_base_simple_max_iter10000__fit_in...                             NaN
#                                                    /gDA_ctrl_0_0_base_simple_max_iter10000__fit_in...                             NaN
#                                                    /gDA_ctrl_0_0_base_simple_max_iter10000__fit_in...                             NaN
#                                                    /gDA_ctrl_0_1_base_words_max_iter10000__fit_int...                       -0.046514
#                                                    /gDA_ctrl_0_1_base_words_max_iter10000__fit_int...                       -0.030282
#                                                    /gDA_ctrl_0_1_base_words_max_iter10000__fit_int...                        0.128489
#                                                    /gDA_ctrl_0_1_base_words_max_iter10000__fit_int...                       -0.133600
#                                                    /gDA_ctrl_0_1_base_words_max_iter10000__fit_int...                        0.083749
#                                                    /gDA_ctrl_0_1_base_words_max_iter10000__fit_int...                       -0.033504
#                                                    /gDA_ctrl_0_1_base_words_max_iter10000__fit_int...                       -0.215454
#                                                    /gDA_ctrl_0_1_base_words_max_iter10000__fit_int...                       -0.096776
#                                                    /gDA_ctrl_0_1_base_words_max_iter10000__fit_int...                        0.075013
#                                                    /gDA_ctrl_0_1_base_words_max_iter10000__fit_int...                       -0.144949
# C:\Users\Josh\Documents\GitHub\sabatinilab-glm\... /gDA_tet_1_0_base_simple_max_iter10000__fit_int...                             NaN
#                                                    /gDA_tet_1_0_base_simple_max_iter10000__fit_int...                             NaN
#                                                    /gDA_tet_1_0_base_simple_max_iter10000__fit_int...                             NaN
#                                                    /gDA_tet_1_0_base_simple_max_iter10000__fit_int...                             NaN
#                                                    /gDA_tet_1_0_base_simple_max_iter10000__fit_int...                             NaN
#                                                    /gDA_tet_1_0_base_simple_max_iter10000__fit_int...                             NaN
#                                                    /gDA_tet_1_0_base_simple_max_iter10000__fit_int...                             NaN
#                                                    /gDA_tet_1_0_base_simple_max_iter10000__fit_int...                             NaN
#                                                    /gDA_tet_1_0_base_simple_max_iter10000__fit_int...                             NaN
#                                                    /gDA_tet_1_0_base_simple_max_iter10000__fit_int...                             NaN
#                                                    /gDA_tet_1_1_base_words_max_iter10000__fit_inte...                       -0.301163
#                                                    /gDA_tet_1_1_base_words_max_iter10000__fit_inte...                       -0.228695
#                                                    /gDA_tet_1_1_base_words_max_iter10000__fit_inte...                       -0.266063
#                                                    /gDA_tet_1_1_base_words_max_iter10000__fit_inte...                       -0.158108
#                                                    /gDA_tet_1_1_base_words_max_iter10000__fit_inte...                       -0.205094
#                                                    /gDA_tet_1_1_base_words_max_iter10000__fit_inte...                       -0.220060
#                                                    /gDA_tet_1_1_base_words_max_iter10000__fit_inte...                       -0.214629
#                                                    /gDA_tet_1_1_base_words_max_iter10000__fit_inte...                       -0.134620
#                                                    /gDA_tet_1_1_base_words_max_iter10000__fit_inte...                       -0.236270
#                                                    /gDA_tet_1_1_base_words_max_iter10000__fit_inte...                       -0.254290
#
# [40 rows x 648 columns]

# %%
fh.create_folder_if_not_exists(out_loc)

# %%
base_keys = list({
                # 'gACH':(0,0),
                # 'rDA':(0,0),
                # 'gDA':(0,0),
                'photometryCenterInIndex':(0,0),
                'photometryCenterOutIndex':(0,0),
                'photometrySideInIndex':(0,0),
                'photometrySideInIndexr':(0,0),
                'photometrySideOutIndex':(0,0),
                'sl': (0,0),
                'spnnrOff': (0,0),
                'photometryCenterInIndex':(0,0),
                'photometryCenterOutIndex':(0,0),
                'photometrySideInIndexAA':(0,0),
                'photometrySideInIndexAa':(0,0),
                'photometrySideInIndexaA':(0,0),
                'photometrySideInIndexaa':(0,0),
                'photometrySideInIndexAB':(0,0),
                'photometrySideInIndexAb':(0,0),
                'photometrySideInIndexaB':(0,0),
                'photometrySideInIndexab':(0,0),
                'photometrySideOutIndex':(0,0),
                'sl': (0,0),
                'spnnrOff': (0,0),
                }.keys())
# base_keys

# %%
save_mse_scatter = concat.reset_index().set_index(['mouse_id', 'channel', 'name', 'model_version', 'run_num'])[['mse_tr', 'mse_cv', 'mse_te']]
save_mse_scatter.to_csv(str((Path(out_loc) / f'{load_folder.parts[-1]}-mse_sctr.csv').resolve()))

save_r2_scatter = concat.reset_index().set_index(['mouse_id', 'channel', 'name', 'model_version', 'run_num'])[['r2_tr', 'r2_cv', 'r2_te']]
save_r2_scatter.to_csv(str((Path(out_loc) / f'{load_folder.parts[-1]}-r2_sctr.csv').resolve()))

# %%
agg = concat.drop(['channel_name', 'timestamp', 'run_num'], axis=1).groupby(['channel', 'name']).agg([np.size, np.mean, np.std])
stk = agg[['mse_tr', 'mse_cv', 'mse_te']].rename({'mse_tr':'01_mse_tr', 'mse_cv':'02_mse_cv', 'mse_te':'03_mse_te'}, axis=1).swaplevel(axis=1).stack()

stk['lb'] = stk['mean'] - 1.96*stk['std']/np.sqrt(stk['size'])
stk['mn'] = stk['mean']
stk['ub'] = stk['mean'] + 1.96*stk['std']/np.sqrt(stk['size'])

plt_df = stk[['lb', 'mn', 'ub']].unstack().swaplevel(axis=1)

gACH = plt_df.loc['gACH'] if 'gACH' in plt_df.reset_index()['channel'].unique() else plt_df.iloc[0:0]
rDA = plt_df.loc['rDA'] if 'rDA' in plt_df.reset_index()['channel'].unique() else plt_df.iloc[0:0]
gDA = plt_df.loc['gDA'] if 'gDA' in plt_df.reset_index()['channel'].unique() else plt_df.iloc[0:0]

save_ci = stk[['mean', 'size', 'std']].unstack().swaplevel(axis=1).sort_index(axis=1)
save_ci.to_csv(str((Path(out_loc) / f'{load_folder.parts[-1]}-mse_ci.csv').resolve()))
# Out:
# C:\Users\Josh\AppData\Local\Temp\ipykernel_6948\2044627354.py:1: FutureWarning: ['model_version'] did not aggregate successfully. If any error is raised this will raise in a future version of pandas. Drop these columns/ops to avoid this warning.
#   agg = concat.drop(['channel_name', 'timestamp', 'run_num'], axis=1).groupby(['channel', 'name']).agg([np.size, np.mean, np.std])

# %%
stk
# Out:
#                                    mean  size       std        lb        mn  \
# channel name
# gDA     base_simple 01_mse_tr  0.747809    20  0.025092  0.736812  0.747809
#                     02_mse_cv  0.751330    20  0.027295  0.739368  0.751330
#                     03_mse_te  0.748447    20  0.024968  0.737504  0.748447
#         base_words  01_mse_tr  0.735898    20  0.026481  0.724292  0.735898
#                     02_mse_cv  0.744651    20  0.025267  0.733577  0.744651
#                     03_mse_te  0.740994    20  0.026028  0.729586  0.740994
#
#                                      ub
# channel name
# gDA     base_simple 01_mse_tr  0.758806
#                     02_mse_cv  0.763293
#                     03_mse_te  0.759389
#         base_words  01_mse_tr  0.747504
#                     02_mse_cv  0.755725
#                     03_mse_te  0.752401

# %%
import matplotlib.pyplot as plt

# %%
rot = 15

fig,axes=plt.subplots(3,1,figsize=(10,20))
fig.set_facecolor('w')

if len(gACH) > 0:
    ax = axes[0]
    ax.plot(gACH.index, gACH['01_mse_tr']['mn'], label='mse_tr')
    ax.fill_between(gACH.index, gACH['01_mse_tr']['lb'], gACH['01_mse_tr']['ub'], alpha=0.2, label='mse_tr - CI')
    ax.plot(gACH.index, gACH['02_mse_cv']['mn'], label='mse_cv')
    ax.fill_between(gACH.index, gACH['02_mse_cv']['lb'], gACH['02_mse_cv']['ub'], alpha=0.2, label='mse_cv - CI')
    ax.plot(gACH.index, gACH['03_mse_te']['mn'], label='mse_te')
    ax.fill_between(gACH.index, gACH['03_mse_te']['lb'], gACH['03_mse_te']['ub'], alpha=0.2, label='mse_te - CI')
    print([_.get_text() for _ in ax.xaxis.get_ticklabels()])
    ax.set_title('gACH - GLM MSEs')
    ax.legend()
    ax.grid(True)
    for tick in ax.get_xticklabels():
        tick.set_rotation(rot)

if len(gDA) > 0:
    ax = axes[1]
    ax.plot(gDA.index, gDA['01_mse_tr']['mn'], label='mse_tr')
    ax.fill_between(gDA.index, gDA['01_mse_tr']['lb'], gDA['01_mse_tr']['ub'], alpha=0.2, label='mse_tr - CI')
    ax.plot(gDA.index, gDA['02_mse_cv']['mn'], label='mse_cv')
    ax.fill_between(gDA.index, gDA['02_mse_cv']['lb'], gDA['02_mse_cv']['ub'], alpha=0.2, label='mse_cv - CI')
    ax.plot(gDA.index, gDA['03_mse_te']['mn'], label='mse_te')
    ax.fill_between(gDA.index, gDA['03_mse_te']['lb'], gDA['03_mse_te']['ub'], alpha=0.2, label='mse_te - CI')
    ax.set_title('gDA - GLM MSEs')
    ax.legend()
    ax.grid(True)
    for tick in ax.get_xticklabels():
        tick.set_rotation(rot)

if len(rDA) > 0:
    ax = axes[2]
    ax.plot(rDA.index, rDA['01_mse_tr']['mn'], label='mse_tr')
    ax.fill_between(rDA.index, rDA['01_mse_tr']['lb'], rDA['01_mse_tr']['ub'], alpha=0.2, label='mse_tr - CI')
    ax.plot(rDA.index, rDA['02_mse_cv']['mn'], label='mse_cv')
    ax.fill_between(rDA.index, rDA['02_mse_cv']['lb'], rDA['02_mse_cv']['ub'], alpha=0.2, label='mse_cv - CI')
    ax.plot(rDA.index, rDA['03_mse_te']['mn'], label='mse_te')
    ax.fill_between(rDA.index, rDA['03_mse_te']['lb'], rDA['03_mse_te']['ub'], alpha=0.2, label='mse_te - CI')
    ax.set_title('rDA - GLM MSEs')
    ax.legend()
    ax.grid(True)

    for tick in ax.get_xticklabels():
        tick.set_rotation(rot)

plt.show()
